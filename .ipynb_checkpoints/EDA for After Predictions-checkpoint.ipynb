# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt

import math
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
data = pd.read_csv('Datasets/dataset after prediction/long_term_analisis/GGRM-long_ARIMA_1_2.csv')

# %%
data
# Out:
#            Date  real_price  Close_ARIMA   Close_LSTM
# 0    21/12/2020       41850  42012.20466  33035.35989
# 1    22/12/2020       41325  41840.35597  33035.35228
# 2    23/12/2020       41075  41326.74438  33035.32948
# 3    28/12/2020       41025  41098.76888  33035.31862
# 4    29/12/2020       41075  41031.53932  33035.31645
# ..          ...         ...          ...          ...
# 248  24/12/2021       30525  30589.88651  33034.86437
# 249  27/12/2021       30675  30517.58371  33034.86113
# 250  28/12/2021       30650  30654.33374  33034.86762
# 251  29/12/2021       30650  30612.76812  33034.86654
# 252  30/12/2021       30600  30622.27650          NaN
#
# [253 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         253 non-null    object
#  1   real_price   253 non-null    int64
#  2   Close_ARIMA  253 non-null    float64
#  3   Close_LSTM   252 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.0+ KB

# %%
# data.Date = pd.to_datetime(data.Date)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         253 non-null    object
#  1   real_price   253 non-null    int64
#  2   Close_ARIMA  253 non-null    float64
#  3   Close_LSTM   252 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.0+ KB

# %%
plt.figure()
plt.grid(True)
plt.xlabel('Times')
plt.ylabel('Prices')
plt.plot(data['real_price'], color = 'green', label = 'Real')
plt.plot(data['Close_ARIMA'], color = 'blue', label = 'ARIMA')
plt.plot(data['Close_LSTM'], color = 'red', label = 'LSTM')
plt.title('Real vs ARIMA vs LSTM GGRM Long Term Stock Price Prediction')
plt.legend()
plt.grid(True)
plt.show()
